# %% [markdown]
# ## KNN Item-Based Collaborative Filtering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# To build a movie recommender, I choose MovieLens Datasets.
# URL - https://grouplens.org/datasets/movielens/latest/

# %%
movies_data = pd.read_csv('./Datasets/ml-25m/movies.csv', usecols=['movieId', 'title'])
rating_data = pd.read_csv('./Datasets/ml-25m/ratings.csv', usecols=['userId', 'movieId', 'rating'])

# %% [markdown]
# First, we need to transform the dataframe of ratings into a proper format that can be consumed by a KNN model.

# %%
data = pd.merge(movies_data, rating_data)
user_movie_table = data.iloc[:10000000,:].pivot(
    index = 'title',
    columns = 'userId',
    values = 'rating'
).fillna(0)

# %%
user_movie_table
# Out:
# userId                                      1       2       3       4       \
# title
# 'Til There Was You (1997)                      0.0     0.0     0.0     0.0
# 'burbs, The (1989)                             0.0     0.0     0.0     0.0
# 1-900 (06) (1994)                              0.0     0.0     0.0     0.0
# 101 Dalmatians (1996)                          0.0     0.0     0.0     0.0
# 12 Angry Men (1957)                            0.0     0.0     0.0     0.0
# ...                                            ...     ...     ...     ...
# Young Guns II (1990)                           0.0     0.0     0.0     0.0
# Young Poisoner's Handbook, The (1995)          0.0     0.0     0.0     0.0
# Zero Effect (1998)                             0.0     0.0     0.0     0.0
# Zero Kelvin (Kjærlighetens kjøtere) (1995)     0.0     0.0     0.0     0.0
# Zeus and Roxanne (1997)                        0.0     0.0     0.0     0.0
#
# userId                                      5       6       7       8       \
# title
# 'Til There Was You (1997)                      0.0     0.0     0.0     0.0
# 'burbs, The (1989)                             0.0     0.0     0.0     0.0
# 1-900 (06) (1994)                              0.0     0.0     0.0     0.0
# 101 Dalmatians (1996)                          0.0     0.0     0.0     0.0
# 12 Angry Men (1957)                            0.0     5.0     0.0     4.0
# ...                                            ...     ...     ...     ...
# Young Guns II (1990)                           0.0     0.0     0.0     0.0
# Young Poisoner's Handbook, The (1995)          0.0     0.0     0.0     0.0
# Zero Effect (1998)                             0.0     0.0     0.0     0.0
# Zero Kelvin (Kjærlighetens kjøtere) (1995)     0.0     0.0     0.0     0.0
# Zeus and Roxanne (1997)                        0.0     0.0     0.0     0.0
#
# userId                                      9       10      ...  162532  \
# title                                                       ...
# 'Til There Was You (1997)                      0.0     0.0  ...     0.0
# 'burbs, The (1989)                             0.0     0.0  ...     0.0
# 1-900 (06) (1994)                              0.0     0.0  ...     0.0
# 101 Dalmatians (1996)                          5.0     0.0  ...     0.0
# 12 Angry Men (1957)                            0.0     0.0  ...     0.0
# ...                                            ...     ...  ...     ...
# Young Guns II (1990)                           1.0     0.0  ...     0.0
# Young Poisoner's Handbook, The (1995)          0.0     0.0  ...     0.0
# Zero Effect (1998)                             0.0     0.0  ...     0.0
# Zero Kelvin (Kjærlighetens kjøtere) (1995)     0.0     0.0  ...     0.0
# Zeus and Roxanne (1997)                        0.0     0.0  ...     0.0
#
# userId                                      162533  162534  162535  162536  \
# title
# 'Til There Was You (1997)                      0.0     0.0     0.0     0.0
# 'burbs, The (1989)                             0.0     0.0     0.0     0.0
# 1-900 (06) (1994)                              0.0     0.0     0.0     0.0
# 101 Dalmatians (1996)                          0.0     0.0     0.0     0.0
# 12 Angry Men (1957)                            0.0     4.5     0.0     0.0
# ...                                            ...     ...     ...     ...
# Young Guns II (1990)                           0.0     0.0     0.0     0.0
# Young Poisoner's Handbook, The (1995)          0.0     0.0     0.0     0.0
# Zero Effect (1998)                             0.0     0.0     0.0     0.0
# Zero Kelvin (Kjærlighetens kjøtere) (1995)     0.0     0.0     0.0     0.0
# Zeus and Roxanne (1997)                        0.0     0.0     0.0     0.0
#
# userId                                      162537  162538  162539  162540  \
# title
# 'Til There Was You (1997)                      0.0     0.0     0.0     0.0
# 'burbs, The (1989)                             0.0     0.0     0.0     0.0
# 1-900 (06) (1994)                              0.0     0.0     0.0     0.0
# 101 Dalmatians (1996)                          0.0     0.0     0.0     3.0
# 12 Angry Men (1957)                            0.0     0.0     0.0     0.0
# ...                                            ...     ...     ...     ...
# Young Guns II (1990)                           0.0     0.0     0.0     0.0
# Young Poisoner's Handbook, The (1995)          0.0     0.0     0.0     0.0
# Zero Effect (1998)                             0.0     0.0     0.0     0.0
# Zero Kelvin (Kjærlighetens kjøtere) (1995)     0.0     0.0     0.0     0.0
# Zeus and Roxanne (1997)                        0.0     0.0     0.0     0.0
#
# userId                                      162541
# title
# 'Til There Was You (1997)                      0.0
# 'burbs, The (1989)                             1.5
# 1-900 (06) (1994)                              0.0
# 101 Dalmatians (1996)                          3.0
# 12 Angry Men (1957)                            0.0
# ...                                            ...
# Young Guns II (1990)                           0.0
# Young Poisoner's Handbook, The (1995)          0.0
# Zero Effect (1998)                             0.0
# Zero Kelvin (Kjærlighetens kjøtere) (1995)     0.0
# Zeus and Roxanne (1997)                        0.0
#
# [1993 rows x 161577 columns]

# %% [markdown]
# ## Let’s Make Some Movie Recommendations

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
recommender = KNeighborsClassifier(n_neighbors = 11, algorithm = 'brute', metric = 'cosine')
recommender.fit(user_movie_table.to_numpy(), user_movie_table.index)
# Out:
# KNeighborsClassifier(algorithm='brute', leaf_size=30, metric='cosine',
#                      metric_params=None, n_jobs=None, n_neighbors=11, p=2,
#                      weights='uniform')

# %%
query = 'Jumanji (1995)'
distances, indices = recommender.kneighbors(user_movie_table.loc[query].values.reshape(1, -1))

# %%
print('recommendations for', query, 'are-', end = '\n\n')

recommendions = []
for i in indices[0]:
    movie = user_movie_table.index[i]
    if movie != query:
        recommendions.append(movie)

for i in recommendions:
    print(i)
# Out:
# recommendations for Jumanji (1995) are-
#
# Mask, The (1994)
# Lion King, The (1994)
# Mrs. Doubtfire (1993)
# Home Alone (1990)
# Jurassic Park (1993)
# Aladdin (1992)
# Speed (1994)
# Beauty and the Beast (1991)
# Santa Clause, The (1994)
# Waterworld (1995)

# %% [markdown]
# ### Our recommender system actually works!!
# ## Now, we have our own movie recommender.
